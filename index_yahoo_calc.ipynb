# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^DJI','^FCHI','^GDAXI']
ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC         ^DJI        ^FCHI       ^GDAXI
# Date
# 1996-12-31  740.739990  1291.030029  6448.270020  2315.699951          NaN
# 1997-01-02  737.010010  1280.699951  6442.490234  2257.000000  2820.810059
# 1997-01-03  748.030029  1310.680054  6544.089844  2282.800049  2863.260010
# 1997-01-06  747.650024  1316.400024  6567.180176  2306.699951  2890.199951
# 1997-01-07  753.229980  1327.729980  6600.660156  2301.699951  2876.340088

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC          ^DJI        ^FCHI        ^GDAXI
# Date
# 2021-08-23  4479.529785  14942.650391  35335.710938  6683.100098  15852.790039
# 2021-08-24  4486.229980  15019.799805  35366.261719  6664.310059  15905.849609
# 2021-08-25  4496.189941  15041.860352  35405.500000  6676.479980  15860.660156
# 2021-08-26  4470.000000  14945.809570  35213.121094  6666.029785  15793.620117
# 2021-08-27  4509.370117  15129.500000  35455.800781  6681.919922  15851.750000

# %%
(ind_data / ind_data.iloc[0]  *  100 ).plot(figsize=(15,6))
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC      ^DJI     ^FCHI    ^GDAXI
# Date
# 2021-08-23  0.008524  0.015494  0.006140  0.008601  0.002831
# 2021-08-24  0.001496  0.005163  0.000865 -0.002812  0.003347
# 2021-08-25  0.002220  0.001469  0.001109  0.001826 -0.002841
# 2021-08-26 -0.005825 -0.006386 -0.005434 -0.001565 -0.004227
# 2021-08-27  0.008808  0.012290  0.006892  0.002384  0.003681

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.091891
# ^IXIC     0.130509
# ^DJI      0.086398
# ^FCHI     0.059446
# ^GDAXI    0.082348
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']
data_2 = pd.DataFrame()
for t in tickers: 
    data_2[t] = wb.DataReader(t,data_source='yahoo', start = '2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2021-08-23  144.350006  4479.529785  35335.710938
# 2021-08-24  143.179993  4486.229980  35366.261719
# 2021-08-25  142.669998  4496.189941  35405.500000
# 2021-08-26  142.419998  4470.000000  35213.121094
# 2021-08-27  142.309998  4509.370117  35455.800781

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize = (15,6))
plt.show()
