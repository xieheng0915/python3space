# %%
import requests
from datetime import datetime,timedelta, timezone
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
url = "api.openweathermap.org/data/2.5/weather?q={city}&appid={key}"

# %%
url = url.format(city="Tokyo,JP", key="a9061fb2cd69275664cf20ec6dc29692")

# %%
jsonData=requests.get(url).json()
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# /var/folders/h7/6j_kxbqs71z8nbtf5drh2jrh0000gn/T/ipykernel_76179/2074257515.py in <module>
# ----> 1 jsonData=requests.get(url).json()
#
# /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
df= pd.DataFrame(columns=["気温"])

# %%
tz = timezone(timedelta(hours = +9), "JST")

# %%
for dat in jsonData:
    jst=str(datetime.fromtimestamp(dat["dt"],tz))[:-9]
    temp = dat["main"]["temp"]
    df.loc[jst]=temp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/h7/6j_kxbqs71z8nbtf5drh2jrh0000gn/T/ipykernel_76179/1071302218.py in <module>
#       1 for dat in jsonData:
# ----> 2     jst=str(datetime.fromtimestamp(dat["dt"],tz))[:-9]
#       3     temp = dat["main"]["temp"]
#       4     df.loc[jst]=temp
#
# TypeError: string indices must be integers

# %%
df.plot(figsize=(16,8))
# Out:
# <AxesSubplot:>
