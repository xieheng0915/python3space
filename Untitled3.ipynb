# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['PG', 'MSFT', 'F', 'GE']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source='yahoo', start='1995-01-01')['Adj Close']

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6709 entries, 1995-01-03 to 2021-08-24
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PG      6709 non-null   float64
#  1   MSFT    6709 non-null   float64
#  2   F       6709 non-null   float64
#  3   GE      6709 non-null   float64
# dtypes: float64(4)
# memory usage: 262.1 KB

# %%
mydata.head()
# Out:
#                   PG      MSFT         F         GE
# Date
# 1995-01-03  8.063840  2.379199  4.380183  32.931717
# 1995-01-04  7.999201  2.396494  4.498034  32.931717
# 1995-01-05  7.886079  2.356964  4.458752  33.012394
# 1995-01-06  7.902242  2.396494  4.458752  32.850979
# 1995-01-09  7.869921  2.381670  4.537320  32.528118

# %%
mydata.tail(200)
# Out:
#                     PG        MSFT      F          GE
# Date
# 2020-11-06  140.581970  221.685806   7.79   64.563736
# 2020-11-09  135.438873  216.404282   8.20   69.591568
# 2020-11-10  137.666885  209.091385   8.38   71.666542
# 2020-11-11  139.443436  214.581009   8.33   70.948280
# 2020-11-12  139.521942  213.481094   8.21   69.910789
# ...                ...         ...    ...         ...
# 2021-08-18  143.300003  290.730011  13.00  101.410004
# 2021-08-19  144.990005  296.769989  12.67   99.419998
# 2021-08-20  145.089996  304.359985  12.57  100.050003
# 2021-08-23  144.350006  304.649994  12.73  100.970001
# 2021-08-24  143.179993  302.619995  13.08  103.269997
#
# [200 rows x 4 columns]

# %%
mydata.iloc[0]
# Out:
# PG       8.063840
# MSFT     2.379199
# F        4.380183
# GE      32.931717
# Name: 1995-01-03 00:00:00, dtype: float64

# %%
(mydata / mydata.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %%
mydata.plot(figsize=(15,6))
plt.show()

# %%
mydata.loc['1995-01-03']
# Out:
# PG       8.063840
# MSFT     2.379199
# F        4.380183
# GE      32.931717
# Name: 1995-01-03 00:00:00, dtype: float64

# %%
mydata.iloc[0]
# Out:
# PG       8.063840
# MSFT     2.379199
# F        4.380183
# GE      32.931717
# Name: 1995-01-03 00:00:00, dtype: float64

# %%
returns = (mydata / mydata.shift(1)) -1 
returns.head()
# Out:
#                   PG      MSFT         F        GE
# Date
# 1995-01-03       NaN       NaN       NaN       NaN
# 1995-01-04 -0.008016  0.007269  0.026905  0.000000
# 1995-01-05 -0.014142 -0.016495 -0.008733  0.002450
# 1995-01-06  0.002050  0.016771  0.000000 -0.004890
# 1995-01-09 -0.004090 -0.006186  0.017621 -0.009828

# %%
weighs = np.array([0.25,0.25,0.25,0.25])

# %%
np.dot(returns, weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h7/6j_kxbqs71z8nbtf5drh2jrh0000gn/T/ipykernel_55128/3337946844.py in <module>
# ----> 1 np.dot(returns, weights)
#
# NameError: name 'weights' is not defined

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# PG      0.132485
# MSFT    0.229911
# F       0.120462
# GE      0.094034
# dtype: float64

# %%
pfolio_1 = str(round(np.dot(annual_returns, weighs), 5) * 100) +'%'
print(pfolio_1)
# Out:
# 14.421999999999999%

# %%
weights_2 = np.array([0.4,0.4,0.15,0.05])

# %%
pfolio_2 = str(round(np.dot(annual_returns, weights_2), 5) * 100) + '%'
print(pfolio_2)
# Out:
# 16.773%
